# %%
# Path - dataset1
path_dataset1 = "/FileStore/tables/country_vaccinations.csv"

# Path - RDD
path_rdd = "/FileStore/tables/arquivo_rdd-1.txt"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leitura de Dataframe

## Opção 1
df1 = spark.read.format("csv").option("header","true").load(path_dataset1)
 
## Exibindo dataframe com cabeçalho como 1a coluna, mostra log de informação
df1.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#     country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vaccinated|daily_vaccinations_raw|daily_vaccinations|total_vaccinations_per_hundred|people_vaccinated_per_hundred|people_fully_vaccinated_per_hundred|daily_vaccinations_per_million|            vaccines|         source_name|      source_website|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# Afghanistan|     AFG|2021-02-22|               0.0|              0.0|                   null|                  null|              null|                           0.0|                          0.0|                               null|                          null|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-23|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# only showing top 2 rows
#
# </div>

# %%
## Opção 2
df1 = spark.read.format("csv").option("header","false").load(path_dataset1)
 
## Exibindo dataframe sem cabeçalho e valores padrao na 1a coluna
df1.show(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+--------+----------+------------------+-----------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
#         _c0|     _c1|       _c2|               _c3|              _c4|                 _c5|                 _c6|               _c7|                 _c8|                 _c9|                _c10|                _c11|                _c12|                _c13|                _c14|
# +-----------+--------+----------+------------------+-----------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
#     country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vacc...|daily_vaccination...|daily_vaccinations|total_vaccination...|people_vaccinated...|people_fully_vacc...|daily_vaccination...|            vaccines|         source_name|      source_website|
# Afghanistan|     AFG|2021-02-22|               0.0|              0.0|                null|                null|              null|                 0.0|                 0.0|                null|                null|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-23|              null|             null|                null|                null|            1367.0|                null|                null|                null|                34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-24|              null|             null|                null|                null|            1367.0|                null|                null|                null|                34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# +-----------+--------+----------+------------------+-----------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 4 rows
#
# </div>

# %%
## Opção 3 de leitura direta
df1 = spark.read.csv(path_dataset1)
 
## Exibindo dataframe com tipos de dados
df1.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [(&#39;_c0&#39;, &#39;string&#39;),
#  (&#39;_c1&#39;, &#39;string&#39;),
#  (&#39;_c2&#39;, &#39;string&#39;),
#  (&#39;_c3&#39;, &#39;string&#39;),
#  (&#39;_c4&#39;, &#39;string&#39;),
#  (&#39;_c5&#39;, &#39;string&#39;),
#  (&#39;_c6&#39;, &#39;string&#39;),
#  (&#39;_c7&#39;, &#39;string&#39;),
#  (&#39;_c8&#39;, &#39;string&#39;),
#  (&#39;_c9&#39;, &#39;string&#39;),
#  (&#39;_c10&#39;, &#39;string&#39;),
#  (&#39;_c11&#39;, &#39;string&#39;),
#  (&#39;_c12&#39;, &#39;string&#39;),
#  (&#39;_c13&#39;, &#39;string&#39;),
#  (&#39;_c14&#39;, &#39;string&#39;)]</div>

# %%
# Opção 4 de leitura 
df1 = spark.read.option("header","true").option("inferSchema","true").csv(path_dataset1)

## Exibindo dataframe com col e tipos de dados
df1.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [(&#39;country&#39;, &#39;string&#39;),
#  (&#39;iso_code&#39;, &#39;string&#39;),
#  (&#39;date&#39;, &#39;timestamp&#39;),
#  (&#39;total_vaccinations&#39;, &#39;double&#39;),
#  (&#39;people_vaccinated&#39;, &#39;double&#39;),
#  (&#39;people_fully_vaccinated&#39;, &#39;double&#39;),
#  (&#39;daily_vaccinations_raw&#39;, &#39;double&#39;),
#  (&#39;daily_vaccinations&#39;, &#39;double&#39;),
#  (&#39;total_vaccinations_per_hundred&#39;, &#39;double&#39;),
#  (&#39;people_vaccinated_per_hundred&#39;, &#39;double&#39;),
#  (&#39;people_fully_vaccinated_per_hundred&#39;, &#39;double&#39;),
#  (&#39;daily_vaccinations_per_million&#39;, &#39;double&#39;),
#  (&#39;vaccines&#39;, &#39;string&#39;),
#  (&#39;source_name&#39;, &#39;string&#39;),
#  (&#39;source_website&#39;, &#39;string&#39;)]</div>

# %%
## Opção 5
df1 = spark.read.option("header","true").option("inferSchema","false").csv(path_dataset1)
 
## Exibindo dataframe todo como string para ingestao em raw zone
df1.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [(&#39;country&#39;, &#39;string&#39;),
#  (&#39;iso_code&#39;, &#39;string&#39;),
#  (&#39;date&#39;, &#39;string&#39;),
#  (&#39;total_vaccinations&#39;, &#39;string&#39;),
#  (&#39;people_vaccinated&#39;, &#39;string&#39;),
#  (&#39;people_fully_vaccinated&#39;, &#39;string&#39;),
#  (&#39;daily_vaccinations_raw&#39;, &#39;string&#39;),
#  (&#39;daily_vaccinations&#39;, &#39;string&#39;),
#  (&#39;total_vaccinations_per_hundred&#39;, &#39;string&#39;),
#  (&#39;people_vaccinated_per_hundred&#39;, &#39;string&#39;),
#  (&#39;people_fully_vaccinated_per_hundred&#39;, &#39;string&#39;),
#  (&#39;daily_vaccinations_per_million&#39;, &#39;string&#39;),
#  (&#39;vaccines&#39;, &#39;string&#39;),
#  (&#39;source_name&#39;, &#39;string&#39;),
#  (&#39;source_website&#39;, &#39;string&#39;)]</div>

# %%
## Opção 6
df1 = spark.read.csv(path_dataset1)
df1 = spark.read.option("header","true").option("inferSchema","true").csv(path_dataset1)
 
## Exibindo colunas do dataframe 
df1.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [&#39;country&#39;,
#  &#39;iso_code&#39;,
#  &#39;date&#39;,
#  &#39;total_vaccinations&#39;,
#  &#39;people_vaccinated&#39;,
#  &#39;people_fully_vaccinated&#39;,
#  &#39;daily_vaccinations_raw&#39;,
#  &#39;daily_vaccinations&#39;,
#  &#39;total_vaccinations_per_hundred&#39;,
#  &#39;people_vaccinated_per_hundred&#39;,
#  &#39;people_fully_vaccinated_per_hundred&#39;,
#  &#39;daily_vaccinations_per_million&#39;,
#  &#39;vaccines&#39;,
#  &#39;source_name&#39;,
#  &#39;source_website&#39;]</div>

# %%
#Opacao 7 de leitura com mudanca do delimitador csv
df1 = spark.read.option("header","true").option("delimiter", "|").option("inferSchema","true").csv(path_dataset1)

## Exibindo dataframe delimitado por |
df1.show(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# country,iso_code,date,total_vaccinations,people_vaccinated,people_fully_vaccinated,daily_vaccinations_raw,daily_vaccinations,total_vaccinations_per_hundred,people_vaccinated_per_hundred,people_fully_vaccinated_per_hundred,daily_vaccinations_per_million,vaccines,source_name,source_website|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#                                                                                                                                                                                                                                                                             Afghanistan,AFG,2...|
#                                                                                                                                                                                                                                                                             Afghanistan,AFG,2...|
#                                                                                                                                                                                                                                                                             Afghanistan,AFG,2...|
#                                                                                                                                                                                                                                                                             Afghanistan,AFG,2...|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 4 rows
#
# </div>

# %%
#Cria objeto (lista do python) com linhas de log de informação para usar em logicas 
df1.take(1) #pode passar nro de linha como parametro
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: [Row(country=&#39;Afghanistan&#39;, iso_code=&#39;AFG&#39;, date=&#39;2021-02-22&#39;, total_vaccinations=&#39;0.0&#39;, people_vaccinated=&#39;0.0&#39;, people_fully_vaccinated=None, daily_vaccinations_raw=None, daily_vaccinations=None, total_vaccinations_per_hundred=&#39;0.0&#39;, people_vaccinated_per_hundred=&#39;0.0&#39;, people_fully_vaccinated_per_hundred=None, daily_vaccinations_per_million=None, vaccines=&#39;Johnson&amp;Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing&#39;, source_name=&#39;World Health Organization&#39;, source_website=&#39;https://covid19.who.int/&#39;)]</div>

# %%
# Ingestao na raw zone de arq parquet
df1.write.format("parquet").save("/FileStore/tables/RAW_ZONE_PARQUET/")

#arq ficou dividido em 6 partes
# ==> deu erro na 2a execução porque já existia e não é refeito!!
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3234906095378058&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># Ingestao na raw zone de arq parquet</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>df1<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;parquet&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;/FileStore/tables/RAW_ZONE_PARQUET/&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> <span class="ansi-red-fg">#arq ficou dividido em 6 partes</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">save</span><span class="ansi-blue-fg">(self, path, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    738</span>             self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    739</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 740</span><span class="ansi-red-fg">             </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    741</span>
# <span class="ansi-green-intense-fg ansi-bold">    742</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: path dbfs:/FileStore/tables/RAW_ZONE_PARQUET already exists.</div>

# %%
# Fazer particionamento do arquivo parquet

df1.repartition(2).write.format("parquet").save("/FileStore/tables/RAW_ZONE_PARQUET/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3234906095378059&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># fazer particionamento do arquivo parquet</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>df1<span class="ansi-blue-fg">.</span>repartition<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;parquet&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;/FileStore/tables/RAW_ZONE_PARQUET/&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">save</span><span class="ansi-blue-fg">(self, path, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    738</span>             self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    739</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 740</span><span class="ansi-red-fg">             </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    741</span>
# <span class="ansi-green-intense-fg ansi-bold">    742</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: path dbfs:/FileStore/tables/RAW_ZONE_PARQUET already exists.</div>

# %%
# CORRECAO: fazer particionamento do arquivo parquet

df1.repartition(2).write.format("parquet").mode("overwrite").save("/FileStore/tables/RAW_ZONE_PARQUET/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
### Outras formas de leitura de arquivos com PySpark
 
#path = "/../../arquivoXPTO"
 
## Criando um dataframe a partir de um JSON
#dataframe = spark.read.json(path)
 
## Criando um dataframe a partir de um ORC
#dataframe = spark.read.orc(path)
 
## Criando um dataframe a partir de um PARQUET
#dataframe = spark.read.parquet(path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
## Leitura de um RDD

rdd = sc.textFile(path_rdd)
#rdd.show() = Errado, não é possível exibir um SHOW() de um RDD, somente um Dataframe
rdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[73]: [&#34;&#39;XXXXXcerveja8.99XXXbohemialata&#39;,&#34;,
#  &#34;&#39;refrigerante6.50XXcocacolalata&#39;,&#34;,
#  &#34;&#39;XXXXXXXXaguaXX20bonafontegalao&#39;&#34;]</div>

# %%
## Tentativa de uso do comando show() com RDD
dfff = spark.read.format("csv").load(path_rdd)
dfff.show(4) 

# Exibe tab com única coluna
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----+
#                  _c0| _c1|
# +--------------------+----+
# &#39;XXXXXcerveja8.99...|null|
# &#39;refrigerante6.50...|null|
# &#39;XXXXXXXXaguaXX20...|null|
# +--------------------+----+
#
# </div>

# %%
# Exibicao do RDD com recurso do databricks - display()
dff = spark.read.format("csv").load(path_rdd)
display(dff)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th></tr></thead><tbody><tr><td>'XXXXXcerveja8.99XXXbohemialata'</td><td>null</td></tr><tr><td>'refrigerante6.50XXcocacolalata'</td><td>null</td></tr><tr><td>'XXXXXXXXaguaXX20bonafontegalao'</td><td>null</td></tr></tbody></table></div>

# %%
# Exibicao de dataframe com recurso do databricks - display()
dfff = spark.read.format("csv").load(path_dataset1)
display(dfff)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>_c14</th></tr></thead><tbody><tr><td>country</td><td>iso_code</td><td>date</td><td>total_vaccinations</td><td>people_vaccinated</td><td>people_fully_vaccinated</td><td>daily_vaccinations_raw</td><td>daily_vaccinations</td><td>total_vaccinations_per_hundred</td><td>people_vaccinated_per_hundred</td><td>people_fully_vaccinated_per_hundred</td><td>daily_vaccinations_per_million</td><td>vaccines</td><td>source_name</td><td>source_website</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-22</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-23</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-24</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-25</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-26</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-27</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-28</td><td>8200.0</td><td>8200.0</td><td>null</td><td>null</td><td>1367.0</td><td>0.02</td><td>0.02</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-01</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1580.0</td><td>null</td><td>null</td><td>null</td><td>40.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-02</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1794.0</td><td>null</td><td>null</td><td>null</td><td>45.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-03</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2008.0</td><td>null</td><td>null</td><td>null</td><td>50.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr> ...

# %%
# Criacao de uma tabela temporária
nome_tabela_temporaria = "tempTableDataFrame1"
df1.createOrReplaceTempView(nome_tabela_temporaria)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leitura da tabela temporaria opcao 1
spark.read.table(nome_tabela_temporaria).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#     country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vaccinated|daily_vaccinations_raw|daily_vaccinations|total_vaccinations_per_hundred|people_vaccinated_per_hundred|people_fully_vaccinated_per_hundred|daily_vaccinations_per_million|            vaccines|         source_name|      source_website|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# Afghanistan|     AFG|2021-02-22|               0.0|              0.0|                   null|                  null|              null|                           0.0|                          0.0|                               null|                          null|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-23|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-24|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-25|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-26|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-27|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-28|            8200.0|           8200.0|                   null|                  null|            1367.0|                          0.02|                         0.02|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-01|              null|             null|                   null|                  null|            1580.0|                          null|                         null|                               null|                          40.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-02|              null|             null|                   null|                  null|            1794.0|                          null|                         null|                               null|                          45.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-03|              null|             null|                   null|                  null|            2008.0|                          null|                         null|                               null|                          50.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-04|              null|             null|                   null|                  null|            2221.0|                          null|                         null|                               null|                          56.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-05|              null|             null|                   null|                  null|            2435.0|                          null|                         null|                               null|                          61.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-06|              null|             null|                   null|                  null|            2649.0|                          null|                         null|                               null|                          66.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-07|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-08|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-09|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-10|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-11|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-12|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-13|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# +-----------+--------+----------+------------------+-----------------

# %%
# Renomeada a tabela temporária
nome_tabela_temporaria = "tempTableTerere"
df1.createOrReplaceTempView(nome_tabela_temporaria)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Leitura da tabela temporaria opcao 2
spark.read.table(nome_tabela_temporaria).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#     country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vaccinated|daily_vaccinations_raw|daily_vaccinations|total_vaccinations_per_hundred|people_vaccinated_per_hundred|people_fully_vaccinated_per_hundred|daily_vaccinations_per_million|            vaccines|         source_name|      source_website|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# Afghanistan|     AFG|2021-02-22|               0.0|              0.0|                   null|                  null|              null|                           0.0|                          0.0|                               null|                          null|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-23|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-24|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-25|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-26|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-27|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-28|            8200.0|           8200.0|                   null|                  null|            1367.0|                          0.02|                         0.02|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-01|              null|             null|                   null|                  null|            1580.0|                          null|                         null|                               null|                          40.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-02|              null|             null|                   null|                  null|            1794.0|                          null|                         null|                               null|                          45.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-03|              null|             null|                   null|                  null|            2008.0|                          null|                         null|                               null|                          50.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-04|              null|             null|                   null|                  null|            2221.0|                          null|                         null|                               null|                          56.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-05|              null|             null|                   null|                  null|            2435.0|                          null|                         null|                               null|                          61.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-06|              null|             null|                   null|                  null|            2649.0|                          null|                         null|                               null|                          66.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-07|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-08|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-09|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-10|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-11|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-12|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-13|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# +-----------+--------+----------+------------------+-----------------

# %%
# Uso de SQL para mostrar tab
spark.sql("SELECT * FROM tempTableTerere").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#     country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vaccinated|daily_vaccinations_raw|daily_vaccinations|total_vaccinations_per_hundred|people_vaccinated_per_hundred|people_fully_vaccinated_per_hundred|daily_vaccinations_per_million|            vaccines|         source_name|      source_website|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# Afghanistan|     AFG|2021-02-22|               0.0|              0.0|                   null|                  null|              null|                           0.0|                          0.0|                               null|                          null|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-23|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-24|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-25|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-26|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-27|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-02-28|            8200.0|           8200.0|                   null|                  null|            1367.0|                          0.02|                         0.02|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-01|              null|             null|                   null|                  null|            1580.0|                          null|                         null|                               null|                          40.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-02|              null|             null|                   null|                  null|            1794.0|                          null|                         null|                               null|                          45.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-03|              null|             null|                   null|                  null|            2008.0|                          null|                         null|                               null|                          50.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-04|              null|             null|                   null|                  null|            2221.0|                          null|                         null|                               null|                          56.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-05|              null|             null|                   null|                  null|            2435.0|                          null|                         null|                               null|                          61.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-06|              null|             null|                   null|                  null|            2649.0|                          null|                         null|                               null|                          66.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-07|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-08|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-09|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-10|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-11|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-12|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# Afghanistan|     AFG|2021-03-13|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://covid19.w...|
# +-----------+--------+----------+------------------+-----------------

# %%
#Mostrar somente colunas especificas da tab com comando SQL
spark.sql("SELECT country, iso_code FROM tempTableTerere").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+--------+
#     country|iso_code|
# +-----------+--------+
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# Afghanistan|     AFG|
# +-----------+--------+
# only showing top 20 rows
#
# </div>

# %%
#Mostrar agrupamento do total de registros contados por col país
spark.sql("SELECT count(*) tt, country FROM tempTableTerere Group By country").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----------------+
#  tt|          country|
# +---+-----------------+
# 294|         Kiribati|
# 408|           Guyana|
# 372|           Jersey|
# 338|         Djibouti|
# 377|             Fiji|
# 388|             Iraq|
# 458|          Germany|
# 423|           Jordan|
# 457|           France|
# 457|           Greece|
# 367|           Kosovo|
# 408|         Dominica|
# 376|Equatorial Guinea|
# 431|          Ecuador|
# 451|          Finland|
# 365|            Ghana|
# 424|         Guernsey|
# 439|            India|
# 433|      Isle of Man|
# 362|            Gabon|
# +---+-----------------+
# only showing top 20 rows
#
# </div>

# %%
#Exibe somente 3 registros ou linhas da selecao anterior
dfterere = spark.sql("SELECT count(*) tt, country FROM tempTableTerere Group By country")
dfterere.show(3) #criado dataframe novo
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------+
#  tt| country|
# +---+--------+
# 294|Kiribati|
# 408|  Guyana|
# 372|  Jersey|
# +---+--------+
# only showing top 3 rows
#
# </div>

# %%
#Exibe tipos de dados do novo dataframe
dfterere = spark.sql("SELECT count(*) tt, country FROM tempTableTerere Group By country")
dfterere.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[67]: [(&#39;tt&#39;, &#39;bigint&#39;), (&#39;country&#39;, &#39;string&#39;)]</div>

# %%
# Visualização do Databricks
display(spark.sql("SELECT * FROM tempTableDataFrame1"))

#Nao funciona na VM Everis
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>iso_code</th><th>date</th><th>total_vaccinations</th><th>people_vaccinated</th><th>people_fully_vaccinated</th><th>daily_vaccinations_raw</th><th>daily_vaccinations</th><th>total_vaccinations_per_hundred</th><th>people_vaccinated_per_hundred</th><th>people_fully_vaccinated_per_hundred</th><th>daily_vaccinations_per_million</th><th>vaccines</th><th>source_name</th><th>source_website</th></tr></thead><tbody><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-22</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-23</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-24</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-25</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-26</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-27</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-28</td><td>8200.0</td><td>8200.0</td><td>null</td><td>null</td><td>1367.0</td><td>0.02</td><td>0.02</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-01</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1580.0</td><td>null</td><td>null</td><td>null</td><td>40.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-02</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1794.0</td><td>null</td><td>null</td><td>null</td><td>45.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-03</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2008.0</td><td>null</td><td>null</td><td>null</td><td>50.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-04</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2221.0</td><td>null</td><td>null</td><td>null</td><td>56.0</td><td>Johnson&Johnson, Oxf ...

# %%
# Scala
#import org.apache.spark.sql.functions._
 
# Python - importa PySpark e funcoes col e column (sao identicas)
from pyspark.sql.functions import col, column
 
# Uso das functions col ou column
df1.select(col("country"), col("date"), column("iso_code")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+----------+--------+
#     country|      date|iso_code|
# +-----------+----------+--------+
# Afghanistan|2021-02-22|     AFG|
# Afghanistan|2021-02-23|     AFG|
# Afghanistan|2021-02-24|     AFG|
# Afghanistan|2021-02-25|     AFG|
# Afghanistan|2021-02-26|     AFG|
# Afghanistan|2021-02-27|     AFG|
# Afghanistan|2021-02-28|     AFG|
# Afghanistan|2021-03-01|     AFG|
# Afghanistan|2021-03-02|     AFG|
# Afghanistan|2021-03-03|     AFG|
# Afghanistan|2021-03-04|     AFG|
# Afghanistan|2021-03-05|     AFG|
# Afghanistan|2021-03-06|     AFG|
# Afghanistan|2021-03-07|     AFG|
# Afghanistan|2021-03-08|     AFG|
# Afghanistan|2021-03-09|     AFG|
# Afghanistan|2021-03-10|     AFG|
# Afghanistan|2021-03-11|     AFG|
# Afghanistan|2021-03-12|     AFG|
# Afghanistan|2021-03-13|     AFG|
# +-----------+----------+--------+
# only showing top 20 rows
#
# </div>

# %%
#Selecao de dados por strings que nomeiam col
df1.selectExpr("country", "date", "iso_code").show()

#Mesma saída da selecao anterior, sem usar functions col e column
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+----------+--------+
#     country|      date|iso_code|
# +-----------+----------+--------+
# Afghanistan|2021-02-22|     AFG|
# Afghanistan|2021-02-23|     AFG|
# Afghanistan|2021-02-24|     AFG|
# Afghanistan|2021-02-25|     AFG|
# Afghanistan|2021-02-26|     AFG|
# Afghanistan|2021-02-27|     AFG|
# Afghanistan|2021-02-28|     AFG|
# Afghanistan|2021-03-01|     AFG|
# Afghanistan|2021-03-02|     AFG|
# Afghanistan|2021-03-03|     AFG|
# Afghanistan|2021-03-04|     AFG|
# Afghanistan|2021-03-05|     AFG|
# Afghanistan|2021-03-06|     AFG|
# Afghanistan|2021-03-07|     AFG|
# Afghanistan|2021-03-08|     AFG|
# Afghanistan|2021-03-09|     AFG|
# Afghanistan|2021-03-10|     AFG|
# Afghanistan|2021-03-11|     AFG|
# Afghanistan|2021-03-12|     AFG|
# Afghanistan|2021-03-13|     AFG|
# +-----------+----------+--------+
# only showing top 20 rows
#
# </div>

# %%
# Scala import
# org.apache.spark.sql.types._
 
# Criacao de Schema manualmente no PySpark
from pyspark.sql.types import *
 
dataframe_ficticio = StructType([
                      StructField("col_String_1", StringType()),
                      StructField("col_Integer_2", IntegerType()),
                      StructField("col_Decimal_3", DecimalType())
                              ])
dataframe_ficticio
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[79]: StructType(List(StructField(col_String_1,StringType,true),StructField(col_Integer_2,IntegerType,true),StructField(col_Decimal_3,DecimalType(10,0),true)))</div>

# %%
# Função para gerar Schema (campos/colunas/nomes de colunas)
 
'''
Scala
 
org.apache.spark.sql.types._
 
def getSchema(fields : Array[StructField]) : StructType = {
  new StructType(fields)
}
'''
 
# PySpark
def getSchema(fields):
  return StructType(fields)
  
schema = getSchema([StructField("coluna1", StringType()), StructField("coluna2", StringType()), StructField("coluna3", StringType())])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Mostra  lista do schema
schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[86]: StructType(List(StructField(coluna1,StringType,true),StructField(coluna2,StringType,true),StructField(coluna3,StringType,true)))</div>

# %%
df1.source_website
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[95]: Column&lt;&#39;source_website&#39;&gt;</div>

# %%
# Gravando um novo CSV
 
#path_destino="/FileStore/tables/CSV/"
#nome_arquivo="arquivo.csv"
#path_geral= path_destino + nome_arquivo
#df1.write.format("csv").mode("overwrite").option("sep", "\t").save(path_geral)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Gravando um novo JSON
 
#path_destino="/FileStore/tables/JSON/"
#nome_arquivo="arquivo.json"
#path_geral= path_destino + nome_arquivo
#df1.write.format("json").mode("overwrite").save(path_geral)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Gravando um novo PARQUET
 
#path_destino="/FileStore/tables/PARQUET/"
#nome_arquivo="arquivo.parquet"
#path_geral= path_destino + nome_arquivo
#df1.write.format("parquet").mode("overwrite").save(path_geral)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Gravando um novo ORC
 
#path_destino="/FileStore/tables/ORC/"
#nome_arquivo="arquivo.orc"
#path_geral= path_destino + nome_arquivo
#df1.write.format("orc").mode("overwrite").save(path_geral)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Outros tipos de SELECT
 
#Diferentes formas de selecionar uma coluna
 
from pyspark.sql.functions import *
 
df1.select("country").show(5)
df1.select('country').show(5)
df1.select(col("country")).show(5)
df1.select(column("country")).show(5)
df1.select(expr("country")).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+
#     country|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# +-----------+
#     country|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# +-----------+
#     country|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# +-----------+
#     country|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# +-----------+
#     country|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# </div>

# %%
#Mostrar col do df1 para comparar abaixo com df2
df1.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[105]: [&#39;country&#39;,
#  &#39;iso_code&#39;,
#  &#39;date&#39;,
#  &#39;total_vaccinations&#39;,
#  &#39;people_vaccinated&#39;,
#  &#39;people_fully_vaccinated&#39;,
#  &#39;daily_vaccinations_raw&#39;,
#  &#39;daily_vaccinations&#39;,
#  &#39;total_vaccinations_per_hundred&#39;,
#  &#39;people_vaccinated_per_hundred&#39;,
#  &#39;people_fully_vaccinated_per_hundred&#39;,
#  &#39;daily_vaccinations_per_million&#39;,
#  &#39;vaccines&#39;,
#  &#39;source_name&#39;,
#  &#39;source_website&#39;]</div>

# %%
# Define nova coluna com um valor constante
df2 = df1.withColumn("nova_coluna", lit(1))
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>iso_code</th><th>date</th><th>total_vaccinations</th><th>people_vaccinated</th><th>people_fully_vaccinated</th><th>daily_vaccinations_raw</th><th>daily_vaccinations</th><th>total_vaccinations_per_hundred</th><th>people_vaccinated_per_hundred</th><th>people_fully_vaccinated_per_hundred</th><th>daily_vaccinations_per_million</th><th>vaccines</th><th>source_name</th><th>source_website</th><th>nova_coluna</th></tr></thead><tbody><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-22</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-23</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-24</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-25</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-26</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-27</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-28</td><td>8200.0</td><td>8200.0</td><td>null</td><td>null</td><td>1367.0</td><td>0.02</td><td>0.02</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-01</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1580.0</td><td>null</td><td>null</td><td>null</td><td>40.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-02</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1794.0</td><td>null</td><td>null</td><td>null</td><td>45.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-03</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2008.0</td><td>null</td><td>null</td><td>null</td><td>50.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://covid19.who.int/</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-04</td><td>null</td><td>null</ ...

# %%
# Adicionar coluna
teste = expr("total_vaccinations < 40")
df1.select("country", "total_vaccinations").withColumn("teste", teste).show(10)

#Traz valor booleano na col teste (true ou false) para responder a condição
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+------------------+-----+
#     country|total_vaccinations|teste|
# +-----------+------------------+-----+
# Afghanistan|               0.0| true|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# Afghanistan|            8200.0|false|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# +-----------+------------------+-----+
# only showing top 10 rows
#
# </div>

# %%
# Renomear uma coluna
df1.select(expr("total_vaccinations as total_de_vacinados")).show(5)
df1.select(col("country").alias("pais")).show(5)
df1.select("country").withColumnRenamed("country", "pais").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
# total_de_vacinados|
# +------------------+
#                0.0|
#               null|
#               null|
#               null|
#               null|
# +------------------+
# only showing top 5 rows
#
# +-----------+
#        pais|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# +-----------+
#        pais|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# </div>

# %%
# Remover uma coluna
df3 = df1.drop("country")
df3.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[101]: [&#39;iso_code&#39;,
#  &#39;date&#39;,
#  &#39;total_vaccinations&#39;,
#  &#39;people_vaccinated&#39;,
#  &#39;people_fully_vaccinated&#39;,
#  &#39;daily_vaccinations_raw&#39;,
#  &#39;daily_vaccinations&#39;,
#  &#39;total_vaccinations_per_hundred&#39;,
#  &#39;people_vaccinated_per_hundred&#39;,
#  &#39;people_fully_vaccinated_per_hundred&#39;,
#  &#39;daily_vaccinations_per_million&#39;,
#  &#39;vaccines&#39;,
#  &#39;source_name&#39;,
#  &#39;source_website&#39;]</div>

# %%
# Filtrando dados e ordenando
# where() é um alias para filter(), usado em condicoes.
 
# Seleciona apenas os primeiros registros da coluna "total_vaccinations"
df1.filter(df1.total_vaccinations > 55).orderBy(df1.total_vaccinations).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vaccinated|daily_vaccinations_raw|daily_vaccinations|total_vaccinations_per_hundred|people_vaccinated_per_hundred|people_fully_vaccinated_per_hundred|daily_vaccinations_per_million|            vaccines|         source_name|      source_website|
# +-------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#  Norway|     NOR|2020-12-23|             100.0|            100.0|                   null|                  17.0|              12.0|                           0.0|                          0.0|                               null|                           2.0|Moderna, Pfizer/B...|Norwegian Institu...|https://github.co...|
# Bahamas|     BHS|2021-04-07|           10000.0|          10000.0|                   null|                  null|             300.0|                          2.52|                         2.52|                               null|                         756.0|Johnson&amp;Johnson, ...|Pan American Heal...|https://ais.paho....|
# +-------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# only showing top 2 rows
#
# </div>

# %%
# Filtra por país igual Argentina com data
df1.select(df1.total_vaccinations, df1.date, df1.country).filter(df1.country == "Argentina").show(24)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+----------+---------+
# total_vaccinations|      date|  country|
# +------------------+----------+---------+
#            20487.0|2020-12-29|Argentina|
#            40589.0|2020-12-30|Argentina|
#            43394.0|2020-12-31|Argentina|
#            43521.0|2021-01-01|Argentina|
#            46833.0|2021-01-02|Argentina|
#            47275.0|2021-01-03|Argentina|
#            57735.0|2021-01-04|Argentina|
#            68458.0|2021-01-05|Argentina|
#            78567.0|2021-01-06|Argentina|
#            96788.0|2021-01-07|Argentina|
#           124669.0|2021-01-08|Argentina|
#           134878.0|2021-01-09|Argentina|
#           136053.0|2021-01-10|Argentina|
#           155877.0|2021-01-11|Argentina|
#           175263.0|2021-01-12|Argentina|
#           192029.0|2021-01-13|Argentina|
#           208675.0|2021-01-14|Argentina|
#           226110.0|2021-01-15|Argentina|
#           231993.0|2021-01-16|Argentina|
#           233054.0|2021-01-17|Argentina|
#           242885.0|2021-01-18|Argentina|
#           256132.0|2021-01-19|Argentina|
#           275552.0|2021-01-20|Argentina|
#           289666.0|2021-01-21|Argentina|
# +------------------+----------+---------+
# only showing top 24 rows
#
# </div>

# %%
# Filtra por país igual Brasil com data
df1.select(df1.total_vaccinations, df1.date, df1.country).filter(df1.country == "Brazil").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+----------+-------+
# total_vaccinations|      date|country|
# +------------------+----------+-------+
#              112.0|2021-01-17| Brazil|
#             1109.0|2021-01-18| Brazil|
#            13527.0|2021-01-19| Brazil|
#           105824.0|2021-01-20| Brazil|
#           193699.0|2021-01-21| Brazil|
# +------------------+----------+-------+
# only showing top 5 rows
#
# </div>

# %%
# Filtra por país diferente Argentina
df1.select(df1.total_vaccinations, df1.country).where(df1.country != "Argentina").show(5) # python type
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+-----------+
# total_vaccinations|    country|
# +------------------+-----------+
#                0.0|Afghanistan|
#               null|Afghanistan|
#               null|Afghanistan|
#               null|Afghanistan|
#               null|Afghanistan|
# +------------------+-----------+
# only showing top 5 rows
#
# </div>

# %%
# Mostra valores únicos
df1.select("country").distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#            country|
# +------------------+
#           Djibouti|
#               Fiji|
#            Germany|
#             France|
#           Dominica|
#  Equatorial Guinea|
#            Ecuador|
#            Finland|
#              Gabon|
#     Faeroe Islands|
#   French Polynesia|
#            Estonia|
#            Georgia|
#           Ethiopia|
#           Eswatini|
#             Gambia|
# Dominican Republic|
#   Falkland Islands|
#            England|
#              Egypt|
# +------------------+
# only showing top 20 rows
#
# </div>

# %%
# Especificando vários filtros em comando separados
filtro_vacinas = df1.total_vaccinations < 100
filtro_pais = df1.country.contains("Argentina")
df1.select(df1.total_vaccinations, df1.country, df1.vaccines).where(df1.vaccines.isin("Sputnik V", "Sinovac")).filter(filtro_vacinas).show(5)
df1.select(df1.total_vaccinations, df1.country, df1.vaccines).where(df1.vaccines.isin("Sputnik V", "Sinovac")).filter(filtro_vacinas).withColumn("filtro_pais", filtro_pais).show(5)

#Nao entendi por que não mostra nada
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+-------+--------+
# total_vaccinations|country|vaccines|
# +------------------+-------+--------+
# +------------------+-------+--------+
#
# +------------------+-------+--------+-----------+
# total_vaccinations|country|vaccines|filtro_pais|
# +------------------+-------+--------+-----------+
# +------------------+-------+--------+-----------+
#
# </div>

# %%
"""#######################################################################################################################
Convertendo dados
#######################################################################################################################"""
 
df5 = df1.withColumn("PAISSSSS", col("country").cast("string").alias("PAISSSSSSS"))
df5.select(df5.PAISSSSS).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+
#    PAISSSSS|
# +-----------+
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 2 rows
#
# </div>

# %%
"""#######################################################################################################################
Trabalhando com funções
#######################################################################################################################"""
 
# Usando funções
df1.select(upper(df1.country)).show(3)
df1.select(lower(df1.country)).show(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+
# upper(country)|
# +--------------+
#    AFGHANISTAN|
#    AFGHANISTAN|
#    AFGHANISTAN|
# +--------------+
# only showing top 3 rows
#
# +--------------+
# lower(country)|
# +--------------+
#    afghanistan|
#    afghanistan|
#    afghanistan|
#    afghanistan|
# +--------------+
# only showing top 4 rows
#
# </div>

# %%
# Criando um dataframe genérico
 ## Usa dicionario do Python com chave-valor
d = [{'name': 'Alice', 'age': 1}]
df_A = spark.createDataFrame(d)
df_A.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----+
# age| name|
# +---+-----+
#   1|Alice|
# +---+-----+
#
# </div>

# %%
#Criação de dataframe rdd1
rdd1 = [{"nome": "Marco","idade": 33,"status": 'true'},
{"nome": "Antonio","idade":33,"status": 'true'},
{"nome":"Pereira","idade":33,"status": 'true'},
{"nome":"Helena","idade":30,"status": 'true'},
{"nome":"Fernando","idade":35,"status": 'true'},
{"nome":"Carlos","idade":28,"status": 'true'},
{"nome":"Lisa","idade":26,"status": 'true'},
{"nome":"Candido","idade":75,"status": 'false'},
{"nome":"Vasco","idade":62,"status": 'true'}
]
dff1 = spark.createDataFrame(rdd1)
dff1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------+------+
# idade|    nome|status|
# +-----+--------+------+
#    33|   Marco|  true|
#    33| Antonio|  true|
#    33| Pereira|  true|
#    30|  Helena|  true|
#    35|Fernando|  true|
#    28|  Carlos|  true|
#    26|    Lisa|  true|
#    75| Candido| false|
#    62|   Vasco|  true|
# +-----+--------+------+
#
# </div>

# %%
#Criação de dataframe rdd2
rdd2 = [
{"nome":"Marco","PaisOrigem":"Brasil"},
{"nome":"Helena","PaisOrigem":"Brasil"},
{"nome":"Gabriel","PaisOrigem":"Brasil"},
{"nome":"Vasco","PaisOrigem":"Portugal"},
{"nome":"Medhi","PaisOrigem":"Marocco"}]
 
dff2 = spark.createDataFrame(rdd2)
dff2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-------+
# PaisOrigem|   nome|
# +----------+-------+
#     Brasil|  Marco|
#     Brasil| Helena|
#     Brasil|Gabriel|
#   Portugal|  Vasco|
#    Marocco|  Medhi|
# +----------+-------+
#
# </div>

# %%
#Uso do join nos 2 dataframes para exibir onde nomes sao iguais
join_type = "inner" #mostra tudo que existe
join_condition = dff1.nome == dff2.nome
df3 = dff1.join(dff2, join_condition, join_type)
df3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+------+------+----------+------+
# idade|  nome|status|PaisOrigem|  nome|
# +-----+------+------+----------+------+
#    30|Helena|  true|    Brasil|Helena|
#    33| Marco|  true|    Brasil| Marco|
#    62| Vasco|  true|  Portugal| Vasco|
# +-----+------+------+----------+------+
#
# </div>

# %%
#Junta df da esquerda
join_type = "left_semi"
join_condition = dff1.nome == dff2.nome
df3 = dff1.join(dff2, join_condition, join_type)
df3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+------+------+
# idade|  nome|status|
# +-----+------+------+
#    30|Helena|  true|
#    33| Marco|  true|
#    62| Vasco|  true|
# +-----+------+------+
#
# </div>

# %%
#Junta df da direita e exibe o que não esta na dir
join_type = "right_outer"
join_condition = dff1.nome == dff2.nome
df3 = dff1.join(dff2, join_condition, join_type)
df3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+------+------+----------+-------+
# idade|  nome|status|PaisOrigem|   nome|
# +-----+------+------+----------+-------+
#  null|  null|  null|    Brasil|Gabriel|
#    30|Helena|  true|    Brasil| Helena|
#    33| Marco|  true|    Brasil|  Marco|
#  null|  null|  null|   Marocco|  Medhi|
#    62| Vasco|  true|  Portugal|  Vasco|
# +-----+------+------+----------+-------+
#
# </div>

# %%
#Junta df da esquerda e exibe o que nao esta na esq
join_type = "left_outer"
join_condition = dff1.nome == dff2.nome
df3 = dff1.join(dff2, join_condition, join_type)
df3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------+------+----------+------+
# idade|    nome|status|PaisOrigem|  nome|
# +-----+--------+------+----------+------+
#    33| Antonio|  true|      null|  null|
#    75| Candido| false|      null|  null|
#    28|  Carlos|  true|      null|  null|
#    35|Fernando|  true|      null|  null|
#    30|  Helena|  true|    Brasil|Helena|
#    26|    Lisa|  true|      null|  null|
#    33|   Marco|  true|    Brasil| Marco|
#    33| Pereira|  true|      null|  null|
#    62|   Vasco|  true|  Portugal| Vasco|
# +-----+--------+------+----------+------+
#
# </div>

# %%
#Junta todos os lados
join_type = "full_outer"
join_condition = dff1.nome == dff2.nome
df3 = dff1.join(dff2, join_condition, join_type)
df3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------+------+----------+-------+
# idade|    nome|status|PaisOrigem|   nome|
# +-----+--------+------+----------+-------+
#    33| Antonio|  true|      null|   null|
#    75| Candido| false|      null|   null|
#    28|  Carlos|  true|      null|   null|
#    35|Fernando|  true|      null|   null|
#  null|    null|  null|    Brasil|Gabriel|
#    30|  Helena|  true|    Brasil| Helena|
#    26|    Lisa|  true|      null|   null|
#    33|   Marco|  true|    Brasil|  Marco|
#  null|    null|  null|   Marocco|  Medhi|
#    33| Pereira|  true|      null|   null|
#    62|   Vasco|  true|  Portugal|  Vasco|
# +-----+--------+------+----------+-------+
#
# </div>

# %%
#Junta tudo que nao tem nos 2 df
join_type = "left_anti"
join_condition = dff1.nome == dff2.nome
df3 = dff1.join(dff2, join_condition, join_type)
df3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------+------+
# idade|    nome|status|
# +-----+--------+------+
#    33| Antonio|  true|
#    75| Candido| false|
#    28|  Carlos|  true|
#    35|Fernando|  true|
#    26|    Lisa|  true|
#    33| Pereira|  true|
# +-----+--------+------+
#
# </div>
